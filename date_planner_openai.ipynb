# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.16.2-py3-none-any.whl (267 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.6.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.10.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.6 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.16.2

# %%
from openai import OpenAI
from google.colab import userdata
api_key = userdata.get('OPENAI_API_KEY')

client = OpenAI(api_key=api_key)

def generate_date_plan(occasion, vibe, location, radius, budget, date, time, cuisine, activities, passions, goals):

    prompt = f"""You are a friendly date planner designed to output JSON. Based on the following details,
      generate two detailed date options, including multiple activities and small subactivities to enjoy between the main activities:

    Occasion: {occasion}
    Vibe: {vibe}
    Location: {location}
    Radius: {radius}
    Budget: {budget}
    Date: {date}
    Time: {time}
    Cuisine: {cuisine}
    Activities: {activities}
    Passions: {passions}
    Goals: {goals}


    One plan should be comfortable and familiar, while the other should be adventurous and unique. Each date plan should have two or three
    activities.
    Each main activity should be followed by a suggestion for a subactivity that can be done en route to the next main activity or as a
    brief interlude.
    The vibe should be consistent throughout the date. """

    json_schema = """
      Each date plan should have the following format:
            {
              "date": "date",
              "time": "time",
              "location": "location",
              "budget": "selected budget",
              "vibe": "desired vibe",
              "plans": [
          {
            "option": "option title",
            "activities": [
                  {{
                  "place": "name of the main activity",
                    "address": "address of the place",
                    "cityState": "city, state abbreviation",
                    "createdAt": "date and time that plan is created",
                    "dateOf": "date that the date plan will be taking place",
                    "description": "description of the main activity",
                    "approximatedCost": "approximate cost in dollar signs",
                    "openDateAndTime": "the time that the place opens and closes on that specific day, formatted strictly with only the times",
                    "datePlanStart": "the start time of this date plan mentioned previously, include the local timezone",
                    "datePlanEnd": "the end time of this date plan, including any additional time you'd like to allocate, include the local timezone, and make sure to end the date before the place closes",
                    "socialMediaLink": "link to the social media page related to the date plan idea, if available",
                    "transportationOptions": "transportation options available to reach the date location",
                    "parkingOptions": "specific parking options or details for the date location",
                    "nearbyAttractions": "nearby attractions or points of interest during the date",
                    "bookingLink": "a direct link to book the experience, such as OpenTable, Resy reservation page, or the official website for reservations",
                    "reservation": "whether reservation is recommended or not at the date location",
                    "attire": "details on what attire is recommended to wear at the date location",
                    "subactivities": [
                        {
                            "description": "Brief description of the subactivity",
                            "conversationTopics": "Conversation ideas during the subactivity",
                            "timeRequired": "estimated time required to complete the subactivity"
                        }
]}]}]}
                  """

    response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      response_format={ "type": "json_object" },
      messages=[
        {
          "role": "system",
          "content": prompt
        },
        {
          "role": "user",
          "content": json_schema

        }
      ],

      temperature=0.7,
      max_tokens=2000,
      top_p=1,
      frequency_penalty=0,
      presence_penalty=0
    )

    return response

# %%
# Generate date plan
date_test = generate_date_plan(occasion="Just because",
                               vibe="romantic",
                               location="Palo Alto",
                               radius="Whithin 33 mi",
                               budget="$$$",
                               date="2024-04-5",
                               time="Flexible-11:30PM",
                               cuisine=['Healthy', 'No seafood'],
                               activities=['adventures', 'arts& culture', 'sports&games'],
                               passions="['yoga', 'dancing', 'singing', 'hiking', 'arts', 'comedy']",
                               goals='Learn more about each other')

# %%
date_test.choices[0].message.content
# Out:
# '{\n    "date": "2024-04-05",\n    "time": "Flexible-11:30PM",\n    "location": "Palo Alto",\n    "budget": "$$$",\n    "vibe": "romantic",\n    "plans": [\n        {\n            "option": "Comfortable & Familiar",\n            "activities": [\n                {\n                    "place": "Stanford Dish Hike",\n                    "address": "Stanford Avenue, Palo Alto, CA 94305",\n                    "cityState": "Palo Alto, CA",\n                    "createdAt": "2023-10-21T10:00:00-07:00",\n                    "dateOf": "2024-04-5",\n                    "description": "Enjoy a scenic hike with beautiful views of the Stanford campus and surrounding area.",\n                    "approximatedCost": "$",\n                    "openDateAndTime": "6:00 AM - 6:00 PM",\n                    "datePlanStart": "10:00 AM PDT",\n                    "datePlanEnd": "1:00 PM PDT",\n                    "socialMediaLink": "https://www.instagram.com/stanforddish/",\n                    "transportationOptions": "Car, bike, or walking",\n                    "parkingOptions": "Parking available at the Stanford Ave entrance",\n                    "nearbyAttractions": "Stanford University campus",\n                    "bookingLink": "",\n                    "reservation": "Not required",\n                    "attire": "Comfortable athletic wear and hiking shoes",\n                    "subactivities": [\n                        {\n                            "description": "Take a selfie at the Stanford Dish viewpoint",\n                            "conversationTopics": "Favorite outdoor activities",\n                            "timeRequired": "15 minutes"\n                        }\n                    ]\n                },\n                {\n                    "place": "Coupa Cafe",\n                    "address": "538 Ramona St, Palo Alto, CA 94301",\n                    "cityState": "Palo Alto, CA",\n                    "createdAt": "2023-10-21T10:00:00-07:00",\n                    "dateOf": "2024-04-5",\n                    "description": "Relax and enjoy a cozy ambiance with delicious coffee and light bites.",\n                    "approximatedCost": "$$",\n                    "openDateAndTime": "7:00 AM - 8:00 PM",\n                    "datePlanStart": "1:30 PM PDT",\n                    "datePlanEnd": "3:30 PM PDT",\n                    "socialMediaLink": "https://www.instagram.com/coupacafe/",\n                    "transportationOptions": "Walking",\n                    "parkingOptions": "Street parking available nearby",\n                    "nearbyAttractions": "Palo Alto Art Center",\n                    "bookingLink": "",\n                    "reservation": "Not required",\n                    "attire": "Casual",\n                    "subactivities": [\n                        {\n                            "description": "Share a delicious dessert",\n                            "conversationTopics": "Favorite coffee preferences",\n                            "timeRequired": "30 minutes"\n                        }\n                    ]\n                }\n            ]\n        },\n        {\n            "option": "Adventurous & Unique",\n            "activities": [\n                {\n                    "place": "Urban Putt",\n                    "address": "1096 South Van Ness Ave, San Francisco, CA 94110",\n                    "cityState": "San Francisco, CA",\n                    "createdAt": "2023-10-21T10:00:00-07:00",\n                    "dateOf": "2024-04-5",\n                    "description": "Experience indoor mini-golf with a creative and artistic twist.",\n                    "approximatedCost": "$$",\n                    "openDateAndTime": "11:00 AM - 1:00 AM",\n                    "datePlanStart": "4:00 PM PDT",\n                    "datePlanEnd": "6:00 PM PDT",\n                    "socialMediaLink": "https://www.instagram.com/urbanputt/",\n                    "transportationOptions": "Car or public transportati ...

# %%
{
    "date": "2024-04-05",
    "time": "Flexible-11:30PM",
    "location": "Palo Alto",
    "budget": "$$$",
    "vibe": "romantic",
    "plans": [
        {
            "option": "Comfortable & Familiar",
            "activities": [
                {
                    "place": "Stanford Dish Hike",
                    "address": "Stanford Avenue, Palo Alto, CA 94305",
                    "cityState": "Palo Alto, CA",
                    "createdAt": "2023-10-21T10:00:00-07:00",
                    "dateOf": "2024-04-5",
                    "description": "Enjoy a scenic hike with beautiful views of the Stanford campus and surrounding area.",
                    "approximatedCost": "$",
                    "openDateAndTime": "6:00 AM - 6:00 PM",
                    "datePlanStart": "10:00 AM PDT",
                    "datePlanEnd": "1:00 PM PDT",
                    "socialMediaLink": "https://www.instagram.com/stanforddish/",
                    "transportationOptions": "Car, bike, or walking",
                    "parkingOptions": "Parking available at the Stanford Ave entrance",
                    "nearbyAttractions": "Stanford University campus",
                    "bookingLink": "",
                    "reservation": "Not required",
                    "attire": "Comfortable athletic wear and hiking shoes",
                    "subactivities": [
                        {
                            "description": "Take a selfie at the Stanford Dish viewpoint",
                            "conversationTopics": "Favorite outdoor activities",
                            "timeRequired": "15 minutes"
                        }
                    ]
                },
                {
                    "place": "Coupa Cafe",
                    "address": "538 Ramona St, Palo Alto, CA 94301",
                    "cityState": "Palo Alto, CA",
                    "createdAt": "2023-10-21T10:00:00-07:00",
                    "dateOf": "2024-04-5",
                    "description": "Relax and enjoy a cozy ambiance with delicious coffee and light bites.",
                    "approximatedCost": "$$",
                    "openDateAndTime": "7:00 AM - 8:00 PM",
                    "datePlanStart": "1:30 PM PDT",
                    "datePlanEnd": "3:30 PM PDT",
                    "socialMediaLink": "https://www.instagram.com/coupacafe/",
                    "transportationOptions": "Walking",
                    "parkingOptions": "Street parking available nearby",
                    "nearbyAttractions": "Palo Alto Art Center",
                    "bookingLink": "",
                    "reservation": "Not required",
                    "attire": "Casual",
                    "subactivities": [
                        {
                            "description": "Share a delicious dessert",
                            "conversationTopics": "Favorite coffee preferences",
                            "timeRequired": "30 minutes"
                        }
                    ]
                }
            ]
        },
        {
            "option": "Adventurous & Unique",
            "activities": [
                {
                    "place": "Urban Putt",
                    "address": "1096 South Van Ness Ave, San Francisco, CA 94110",
                    "cityState": "San Francisco, CA",
                    "createdAt": "2023-10-21T10:00:00-07:00",
                    "dateOf": "2024-04-5",
                    "description": "Experience indoor mini-golf with a creative and artistic twist.",
                    "approximatedCost": "$$",
                    "openDateAndTime": "11:00 AM - 1:00 AM",
                    "datePlanStart": "4:00 PM PDT",
                    "datePlanEnd": "6:00 PM PDT",
                    "socialMediaLink": "https://www.instagram.com/urbanputt/",
                    "transportationOptions": "Car or public transportation",
                    "parkingOptions": "Street parking available",
                    "nearbyAttractions": "Mission District murals",
                    "bookingLink": "https://www.urbanputt.com/",
                    "reservation": "Recommended",
                    "attire": "Casual",
                    "subactivities": [
                        {
                            "description": "Compete in a friendly mini-golf challenge",
                            "conversationTopics": "Favorite childhood games",
                            "timeRequired": "1 hour"
                        }
                    ]
                },
                {
                    "place": "BATS Improv",
                    "address": "Bayfront Theater, Building B, Fort Mason Center, San Francisco, CA 94123",
                    "cityState": "San Francisco, CA",
                    "createdAt": "2023-10-21T10:00:00-07:00",
                    "dateOf": "2024-04-5",
                    "description": "Enjoy a night of laughter with live improv comedy performances.",
                    "approximatedCost": "$$",
                    "openDateAndTime": "7:00 PM - 10:00 PM",
                    "datePlanStart": "7:30 PM PDT",
                    "datePlanEnd": "10:30 PM PDT",
                    "socialMediaLink": "https://www.instagram.com/batsimprov/",
                    "transportationOptions": "Car or public transportation",
                    "parkingOptions": "Parking available at Fort Mason Center",
                    "nearbyAttractions": "Golden Gate Bridge",
                    "bookingLink": "https://www.improv.org/",
                    "reservation": "Recommended",
                    "attire": "Casual",
                    "subactivities": [
                        {
                            "description": "Participate in a fun improv game together",
                            "conversationTopics": "Favorite comedy shows or movies",
                            "timeRequired": "1 hour"
                        }
                    ]
                }
            ]
        }
    ]
}
# Out:
# {'date': '2024-04-05',
#  'time': 'Flexible-11:30PM',
#  'location': 'Palo Alto',
#  'budget': '$$$',
#  'vibe': 'romantic',
#  'plans': [{'option': 'Comfortable and Familiar Date',
#    'activities': [{'place': 'Gamble Garden',
#      'address': '1431 Waverley St',
#      'cityState': 'Palo Alto, CA',
#      'createdAt': '2023-10-24T15:30:00-07:00',
#      'dateOf': '2024-04-05',
#      'description': 'Enjoy a peaceful stroll through beautiful gardens and learn about various plant species.',
#      'approximatedCost': '$',
#      'openDateAndTime': '8:00AM-5:00PM',
#      'datePlanStart': 'Flexible',
#      'datePlanEnd': '5:30PM',
#      'socialMediaLink': 'https://www.instagram.com/gamblegarden/',
#      'transportationOptions': 'Car, bike, or walk',
#      'parkingOptions': 'On-site parking available',
#      'nearbyAttractions': 'Palo Alto Art Center, Stanford Shopping Center',
#      'bookingLink': 'https://www.gamblegarden.org/visit/',
#      'reservation': 'Not required',
#      'attire': 'Casual, comfortable clothing',
#      'subactivities': [{'description': 'Visit the gift shop and pick out a small plant as a memento.',
#        'conversationTopics': 'Favorite flowers, gardening experiences',
#        'timeRequired': '20 minutes'}]},
#     {'place': 'Bird Dog',
#      'address': '420 Ramona St',
#      'cityState': 'Palo Alto, CA',
#      'createdAt': '2023-10-24T15:30:00-07:00',
#      'dateOf': '2024-04-05',
#      'description': 'Indulge in modern American dishes with a focus on seasonal ingredients.',
#      'approximatedCost': '$$$',
#      'openDateAndTime': '5:00PM-10:00PM',
#      'datePlanStart': '6:00PM',
#      'datePlanEnd': '8:00PM',
#      'socialMediaLink': 'https://www.instagram.com/birddogpa/',
#      'transportationOptions': 'Walk',
#      'parkingOptions': 'Street parking available',
#      'nearbyAttractions': 'Stanford University, Cantor Arts Center',
#      'bookingLink': 'https://www.birddogpa.com/',
#      'reservation': 'Recommended',
#      'attire': 'Smart casual',
#      'subactivities': [{'description': 'Share a dessert and discuss your favorite childhood foods.',
#        'conversationTopics': 'Food memories, favorite cuisines',
#        'timeRequired': '30 minutes'}]}]}]}

# %%
## OUTPUT preview

  {
    "date": "2024-04-15",
    "time": "7:00 PM",
    "location": "New York",
    "budget": "$$$",
    "vibe": "romantic",
    "plans": [
        {
            "option": "Comfortable and Familiar Date",
            "activities": [
                {
                    "place": "Dinner at Le Bernardin",
                    "address": "155 W 51st St",
                    "cityState": "New York, NY",
                    "createdAt": "2023-10-26T15:00:00-04:00",
                    "dateOf": "2024-04-15",
                    "description": "Enjoy a romantic dinner at the renowned Le Bernardin, known for its exquisite seafood dishes and elegant ambiance.",
                    "approximatedCost": "$$$",
                    "openDateAndTime": "5:15 PM - 10:30 PM",
                    "datePlanStart": "2024-04-15T19:00:00-04:00",
                    "datePlanEnd": "2024-04-15T21:00:00-04:00",
                    "socialMediaLink": "https://www.instagram.com/lebernardinny/",
                    "transportationOptions": "Subway, Taxi, Uber",
                    "parkingOptions": "Street parking or nearby garages",
                    "nearbyAttractions": "Times Square, Rockefeller Center",
                    "bookingLink": "https://www.le-bernardin.com/reservations",
                    "reservation": "Reservation recommended",
                    "attire": "Smart Casual",
                    "subactivities": [
                        {
                            "description": "Stroll through Central Park",
                            "conversationTopics": "Favorite park activities, nature, upcoming events",
                            "timeRequired": "30 minutes"
                        }
                    ]
                },
                {
                    "place": "Broadway Show - The Phantom of the Opera",
                    "address": "245 W 44th St",
                    "cityState": "New York, NY",
                    "createdAt": "2023-10-26T15:00:00-04:00",
                    "dateOf": "2024-04-15",
                    "description": "Experience the timeless magic of The Phantom of the Opera, a classic Broadway musical filled with romance and drama.",
                    "approximatedCost": "$$$",
                    "openDateAndTime": "7:00 PM - 9:30 PM",
                    "datePlanStart": "2024-04-15T21:15:00-04:00",
                    "datePlanEnd": "2024-04-15T23:00:00-04:00",
                    "socialMediaLink": "https://www.instagram.com/phantombroadway/",
                    "transportationOptions": "Walking, Taxi, Uber",
                    "parkingOptions": "Nearby parking garages",
                    "nearbyAttractions": "Theater District, Times Square",
                    "bookingLink": "https://www.broadway.com/shows/phantom-opera/",
                    "reservation": "Ticket purchase required",
                    "attire": "Smart Casual",
                    "subactivities": [
                        {
                            "description": "Grab a post-show dessert at Junior's",
                            "conversationTopics": "Favorite desserts, theater experience, memorable moments",
                            "timeRequired": "20 minutes"
                        }
                    ]
                }
            ]
        },
        {
            "option": "Adventurous and Unique Date",
            "activities": [
                {
                    "place": "Sunset Helicopter Tour",
                    "address": "Downtown Manhattan Heliport",
                    "cityState": "New York, NY",
                    "createdAt": "2023-10-26T15:00:00-04:00",
                    "dateOf": "2024-04-15",
                    "description": "Embark on a romantic helicopter tour at sunset to see the stunning skyline of New York City from a unique perspective.",
                    "approximatedCost": "$$$",
                    "openDateAndTime": "6:00 PM - 8:00 PM",
                    "datePlanStart": "2024-04-15T19:00:00-04:00",
                    "datePlanEnd": "2024-04-15T20:00:00-04:00",
                    "socialMediaLink": "https://www.instagram.com/libertyhelicopters/",
                    "transportationOptions": "Taxi, Uber",
                    "parkingOptions": "Parking available at the heliport",
                    "nearbyAttractions": "Statue of Liberty, One World Observatory",
                    "bookingLink": "https://www.libertyhelicopter.com/",
                    "reservation": "Reservation required",
                    "attire": "Casual",
                    "subactivities": [
                        {
                            "description": "Walk along the Hudson River Park",
                            "conversationTopics": "City views, favorite outdoor activities, future adventures",
                            "timeRequired": "20 minutes"
                        }
                    ]
                },
                {
                    "place": "Dessert Tasting at Spot Dessert Bar",
                    "address": "13 St Marks Pl",
                    "cityState": "New York, NY",
                    "createdAt": "2023-10-26T15:00:00-04:00",
                    "dateOf": "2024-04-15",
                    "description": "Indulge in a unique dessert tasting experience at Spot Dessert Bar, known for its innovative and delicious sweet creations.",
                    "approximatedCost": "$$$",
                    "openDateAndTime": "6:00 PM - 11:00 PM",
                    "datePlanStart": "2024-04-15T20:30:00-04:00",
                    "datePlanEnd": "2024-04-15T21:30:00-04:00",
                    "socialMediaLink": "https://www.instagram.com/spotdessertbar/",
                    "transportationOptions": "Walking, Taxi, Uber",
                    "parkingOptions": "Street parking or nearby garages",
                    "nearbyAttractions": "East Village, Union Square",
                    "bookingLink": "https://www.spotdessertbar.com/",
                    "reservation": "Walk-ins accepted",
                    "attire": "Casual",
                    "subactivities": [
                        {
                            "description": "Explore the vibrant East Village streets",
                            "conversationTopics": "Local culture, hidden gems, favorite cuisines",
                            "timeRequired": "30 minutes"
                        }
                    ]
                }
            ]
        }
    ]
}

# %%
import json

# %%
# Convert string output to JSON
dates = json.loads(date_test.choices[0].message.content)

# %%
# Preview
dates
# Out:
# {'date': '2024-04-15',
#  'time': '7:00 PM',
#  'location': 'New York',
#  'budget': '$$$',
#  'vibe': 'romantic',
#  'plans': [{'option': 'Comfortable and Familiar Date',
#    'activities': [{'place': 'Dinner at Le Bernardin',
#      'address': '155 W 51st St',
#      'cityState': 'New York, NY',
#      'createdAt': '2023-10-26T15:00:00-04:00',
#      'dateOf': '2024-04-15',
#      'description': 'Enjoy a romantic dinner at the renowned Le Bernardin, known for its exquisite seafood dishes and elegant ambiance.',
#      'approximatedCost': '$$$',
#      'openDateAndTime': '5:15 PM - 10:30 PM',
#      'datePlanStart': '2024-04-15T19:00:00-04:00',
#      'datePlanEnd': '2024-04-15T21:00:00-04:00',
#      'socialMediaLink': 'https://www.instagram.com/lebernardinny/',
#      'transportationOptions': 'Subway, Taxi, Uber',
#      'parkingOptions': 'Street parking or nearby garages',
#      'nearbyAttractions': 'Times Square, Rockefeller Center',
#      'bookingLink': 'https://www.le-bernardin.com/reservations',
#      'reservation': 'Reservation recommended',
#      'attire': 'Smart Casual',
#      'subactivities': [{'description': 'Stroll through Central Park',
#        'conversationTopics': 'Favorite park activities, nature, upcoming events',
#        'timeRequired': '30 minutes'}]},
#     {'place': 'Broadway Show - The Phantom of the Opera',
#      'address': '245 W 44th St',
#      'cityState': 'New York, NY',
#      'createdAt': '2023-10-26T15:00:00-04:00',
#      'dateOf': '2024-04-15',
#      'description': 'Experience the timeless magic of The Phantom of the Opera, a classic Broadway musical filled with romance and drama.',
#      'approximatedCost': '$$$',
#      'openDateAndTime': '7:00 PM - 9:30 PM',
#      'datePlanStart': '2024-04-15T21:15:00-04:00',
#      'datePlanEnd': '2024-04-15T23:00:00-04:00',
#      'socialMediaLink': 'https://www.instagram.com/phantombroadway/',
#      'transportationOptions': 'Walking, Taxi, Uber',
#      'parkingOptions': 'Nearby parking garages',
#      'nearbyAttractions': 'Theater District, Times Square',
#      'bookingLink': 'https://www.broadway.com/shows/phantom-opera/',
#      'reservation': 'Ticket purchase required',
#      'attire': 'Smart Casual',
#      'subactivities': [{'description': "Grab a post-show dessert at Junior's",
#        'conversationTopics': 'Favorite desserts, theater experience, memorable moments',
#        'timeRequired': '20 minutes'}]}]},
#   {'option': 'Adventurous and Unique Date',
#    'activities': [{'place': 'Sunset Helicopter Tour',
#      'address': 'Downtown Manhattan Heliport',
#      'cityState': 'New York, NY',
#      'createdAt': '2023-10-26T15:00:00-04:00',
#      'dateOf': '2024-04-15',
#      'description': 'Embark on a romantic helicopter tour at sunset to see the stunning skyline of New York City from a unique perspective.',
#      'approximatedCost': '$$$',
#      'openDateAndTime': '6:00 PM - 8:00 PM',
#      'datePlanStart': '2024-04-15T19:00:00-04:00',
#      'datePlanEnd': '2024-04-15T20:00:00-04:00',
#      'socialMediaLink': 'https://www.instagram.com/libertyhelicopters/',
#      'transportationOptions': 'Taxi, Uber',
#      'parkingOptions': 'Parking available at the heliport',
#      'nearbyAttractions': 'Statue of Liberty, One World Observatory',
#      'bookingLink': 'https://www.libertyhelicopter.com/',
#      'reservation': 'Reservation required',
#      'attire': 'Casual',
#      'subactivities': [{'description': 'Walk along the Hudson River Park',
#        'conversationTopics': 'City views, favorite outdoor activities, future adventures',
#        'timeRequired': '20 minutes'}]},
#     {'place': 'Dessert Tasting at Spot Dessert Bar',
#      'address': '13 St Marks Pl',
#      'cityState': 'New York, NY',
#      'createdAt': '2023-10-26T15:00:00-04:00',
#      'dateOf': '2024-04-15',
#      'description': 'Indulge in a unique dessert tasting experience at Spot Dessert Bar, known for its innovative and delicious sweet creations.',
#      'approximatedCost': '$$$',
#      'openDateAndTime': '6:00 PM - 11:00 PM',
#      'datePlanStart': '2024-04-15T20:30:00-04:00',
#      'datePlanEnd': '2024-04-15T21:30:00-04:00',
#      'socialMediaLink': 'https://www.instagram.com/spotdessertbar/',
#      'transportationOptions': 'Walking, Taxi, Uber',
#      'parkingOptions': 'Street parking or nearby garages',
#      'nearbyAttractions': 'East Village, Union Square',
#      'bookingLink': 'https://www.spotdessertbar.com/',
#      'reservation': 'Walk-ins accepted',
#      'attire': 'Casual',
#      'subactivities': [{'description': 'Explore the vibrant East Village streets',
#        'conversationTopics': 'Local culture, hidden gems, favorite cuisines',
#        'timeRequired': '30 minutes'}]}]}]}

# %%
# Get date option 1 acitivity 1

dates['plans'][0]['activities'][0]
# Out:
# {'place': 'Dinner at Le Bernardin',
#  'address': '155 W 51st St',
#  'cityState': 'New York, NY',
#  'createdAt': '2023-10-26T15:00:00-04:00',
#  'dateOf': '2024-04-15',
#  'description': 'Enjoy a romantic dinner at the renowned Le Bernardin, known for its exquisite seafood dishes and elegant ambiance.',
#  'approximatedCost': '$$$',
#  'openDateAndTime': '5:15 PM - 10:30 PM',
#  'datePlanStart': '2024-04-15T19:00:00-04:00',
#  'datePlanEnd': '2024-04-15T21:00:00-04:00',
#  'socialMediaLink': 'https://www.instagram.com/lebernardinny/',
#  'transportationOptions': 'Subway, Taxi, Uber',
#  'parkingOptions': 'Street parking or nearby garages',
#  'nearbyAttractions': 'Times Square, Rockefeller Center',
#  'bookingLink': 'https://www.le-bernardin.com/reservations',
#  'reservation': 'Reservation recommended',
#  'attire': 'Smart Casual',
#  'subactivities': [{'description': 'Stroll through Central Park',
#    'conversationTopics': 'Favorite park activities, nature, upcoming events',
#    'timeRequired': '30 minutes'}]}

# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.16.2-py3-none-any.whl (267 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.6.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.10.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.6 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.16.2

# %%
from openai import OpenAI
from google.colab import userdata
api_key = userdata.get('OPENAI_API_KEY')

client = OpenAI(api_key=api_key)

def generate_date_plan_test(preferences):

    prompt = f"""You are a friendly date planner designed to output JSON. Based on the following details,
      generate two detailed date options, including multiple activities and small subactivities to enjoy between the main activities:

    #Basics
    Occasion: {preferences['occasion']}
    Date: {preferences['date']}
    Time: {preferences['time']}
    Accomodations: {preferences['accommodations']}

    #Details
    Budget per person: {preferences['budget']}
    Fun Stops: {preferences['fun_stops']}
    Location: {preferences['location']}
    Distance radius: {preferences['radius']}

    #Activities
    Plan Itinerary or Go with the Flow: {preferences['make_itinerary']}
    SpecificActivity: {preferences['specific_activity']}
    Cuisine: {preferences['cuisine']}
    Hobbies: {preferences['hobbies']}

    #Relationship Goals
    Goals: {preferences['goals']}
    """

    instructions = """Generate TWO DETAILED DATE OPTIONS. One plan should be comfortable and familiar, while the other should be adventurous and unique. Each date plan should have two or three
    activities.
    Each main activity should be followed by a suggestion for a subactivity that can be done en route to the next main activity or as a
    brief interlude.
    The vibe should be consistent throughout the date."""

    json_schema = """
      Each date plan should have the following format:
            {
              "date": "",
              "time": "",
              "location": "",
              "budget": "",
              "vibe": "",
              "plans": [
          {
            "option": "",
            "activities": [
                  {{
                  "place": "",
                    "address": "",
                    "cityState": "",
                    "createdAt": "",
                    "dateOf": "",
                    "description": "",
                    "approximatedCost": "",
                    "openDateAndTime": "",
                    "datePlanStart": "",
                    "datePlanEnd": "",
                    "socialMediaLink": "",
                    "transportationOptions": "",
                    "parkingOptions": "",
                    "nearbyAttractions": "",
                    "bookingLink": "",
                    "reservation": "",
                    "attire": "",
                    "subactivities": [
                        {
                            "description": "",
                            "conversationTopics": "",
                            "timeRequired": ""
                        }
]}]}]}
                  """

    response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      response_format={ "type": "json_object" },
      messages=[
        {
          "role": "system",
          "content": prompt
        },
        {
          "role": "user",
          "content": instructions
        },
        {
          "role": "user",
          "content": json_schema

        }
      ],

      temperature=0.5,
      max_tokens=2000,
      top_p=1,
      frequency_penalty=0,
      presence_penalty=0
    )

    return response

# %%
user_preferences = {
    "occasion": "Just because",
    "date": "April 10, 2024",
    "time": "7PM",
    "accommodations": "Child-friendly",
    "budget": "$$",
    "fun_stops": "2",
    "location": "New York",
    "radius": "Within 10 mile",
    "make_itinerary": "Yes",
    "specific_activity": "Culinary",
    "cuisine": "Japanese",
    "hobbies": "adventures, sports, comedy",
    "goals": "Experience something new"
}

# %%
date_test_2 = generate_date_plan_test(user_preferences)

# %%
date_test_2
# Out:
# ChatCompletion(id='chatcmpl-9AdrOks3wAQq85GcCMf0kQ3Yio0eV', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "date": "April 10, 2024",\n    "time": "7:00 PM",\n    "location": "New York",\n    "budget": "$$",\n    "vibe": "Comfortable and Familiar",\n    "plans": [\n        {\n            "option": "Comfortable and Familiar Date",\n            "activities": [\n                {\n                    "place": "Sakagura East Village",\n                    "address": "211 E 43rd St B1, New York, NY 10017",\n                    "cityState": "New York, NY",\n                    "createdAt": "1996",\n                    "dateOf": "April 10, 2024",\n                    "description": "Enjoy an authentic Japanese dining experience at Sakagura East Village known for its traditional dishes and sake selection.",\n                    "approximatedCost": "$$",\n                    "openDateAndTime": "7:00 PM",\n                    "datePlanStart": "7:00 PM",\n                    "datePlanEnd": "9:00 PM",\n                    "socialMediaLink": "https://www.instagram.com/sakagura_east_village/",\n                    "transportationOptions": "Subway, Taxi, Car",\n                    "parkingOptions": "Street Parking, Garage Parking",\n                    "nearbyAttractions": "Grand Central Terminal, Bryant Park",\n                    "bookingLink": "https://www.opentable.com/r/sakagura-new-york",\n                    "reservation": "Recommended",\n                    "attire": "Smart Casual",\n                    "subactivities": [\n                        {\n                            "description": "Take a leisurely stroll around Bryant Park",\n                            "conversationTopics": "Favorite Japanese dishes, upcoming travel plans",\n                            "timeRequired": "30 minutes"\n                        }\n                    ]\n                },\n                {\n                    "place": "Comedy Cellar",\n                    "address": "117 Macdougal St, New York, NY 10012",\n                    "cityState": "New York, NY",\n                    "createdAt": "1982",\n                    "dateOf": "April 10, 2024",\n                    "description": "Laugh the night away at Comedy Cellar, a renowned comedy club featuring top comedians and a vibrant atmosphere.",\n                    "approximatedCost": "$$",\n                    "openDateAndTime": "9:30 PM",\n                    "datePlanStart": "9:30 PM",\n                    "datePlanEnd": "11:00 PM",\n                    "socialMediaLink": "https://www.instagram.com/comedycellarusa/",\n                    "transportationOptions": "Subway, Taxi, Car",\n                    "parkingOptions": "Street Parking, Garage Parking",\n                    "nearbyAttractions": "Washington Square Park, NYU Campus",\n                    "bookingLink": "https://www.comedycellar.com/",\n                    "reservation": "Recommended",\n                    "attire": "Casual",\n                    "subactivities": [\n                        {\n                            "description": "Grab a coffee at a nearby cafe and discuss your favorite comedians",\n                            "conversationTopics": "Stand-up comedy, funny life experiences",\n                            "timeRequired": "20 minutes"\n                        }\n                    ]\n                }\n            ]\n        }\n    ]\n}\n    \n   \n\n\n ', role='assistant', function_call=None, tool_calls=None))], created=1712323530, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint='fp_b28b39ffa8', usage=CompletionUsage(completion_tokens=665, prompt_tokens=452, total_tokens=1117))

# %%
date_test.choices[0].message.content
# Out:
# '{\n    "date": "April 10, 2024",\n    "time": "7:00 PM",\n    "location": "New York",\n    "budget": "$$",\n    "vibe": "Comfortable and Familiar",\n    "plans": [\n        {\n            "option": "Comfortable and Familiar Date",\n            "activities": [\n                {\n                    "place": "Sakagura",\n                    "address": "211 E 43rd St, New York, NY 10017",\n                    "cityState": "New York, NY",\n                    "createdAt": "1996",\n                    "dateOf": "2024",\n                    "description": "Enjoy authentic Japanese cuisine in a cozy and intimate setting at Sakagura.",\n                    "approximatedCost": "$$-$$$",\n                    "openDateAndTime": "7:00 PM",\n                    "datePlanStart": "7:00 PM",\n                    "datePlanEnd": "9:00 PM",\n                    "socialMediaLink": "https://www.instagram.com/sakagura.nyc/",\n                    "transportationOptions": "Subway, Taxi",\n                    "parkingOptions": "Street Parking, Parking Garages",\n                    "nearbyAttractions": "Grand Central Terminal, Bryant Park",\n                    "bookingLink": "https://www.sakagura.com/reservations/",\n                    "reservation": "Recommended",\n                    "attire": "Casual",\n                    "subactivities": [\n                        {\n                            "description": "Take a leisurely stroll through Bryant Park",\n                            "conversationTopics": "Favorite outdoor activities, childhood memories",\n                            "timeRequired": "30 minutes"\n                        }\n                    ]\n                },\n                {\n                    "place": "Comedy Cellar",\n                    "address": "117 Macdougal St, New York, NY 10012",\n                    "cityState": "New York, NY",\n                    "createdAt": "1982",\n                    "dateOf": "2024",\n                    "description": "Laugh the night away at the legendary Comedy Cellar with top stand-up comedians.",\n                    "approximatedCost": "$$",\n                    "openDateAndTime": "9:30 PM",\n                    "datePlanStart": "9:30 PM",\n                    "datePlanEnd": "11:00 PM",\n                    "socialMediaLink": "https://www.instagram.com/comedycellarusa/",\n                    "transportationOptions": "Subway, Taxi",\n                    "parkingOptions": "Street Parking",\n                    "nearbyAttractions": "Washington Square Park, NYU Campus",\n                    "bookingLink": "https://www.comedycellar.com/",\n                    "reservation": "Recommended",\n                    "attire": "Casual",\n                    "subactivities": [\n                        {\n                            "description": "Enjoy a quick walk around Washington Square Park",\n                            "conversationTopics": "Favorite comedians, funny childhood stories",\n                            "timeRequired": "20 minutes"\n                        }\n                    ]\n                }\n            ]\n        }\n    ]\n}'

# %%
{
    "date": "April 10, 2024",
    "time": "7:00 PM",
    "location": "New York",
    "budget": "$$",
    "vibe": "Comfortable and Familiar",
    "plans": [
        {
            "option": "Comfortable and Familiar Date",
            "activities": [
                {
                    "place": "Sakagura",
                    "address": "211 E 43rd St, New York, NY 10017",
                    "cityState": "New York, NY",
                    "createdAt": "1996",
                    "dateOf": "2024",
                    "description": "Enjoy authentic Japanese cuisine in a cozy and intimate setting at Sakagura.",
                    "approximatedCost": "$$-$$$",
                    "openDateAndTime": "7:00 PM",
                    "datePlanStart": "7:00 PM",
                    "datePlanEnd": "9:00 PM",
                    "socialMediaLink": "https://www.instagram.com/sakagura.nyc/",
                    "transportationOptions": "Subway, Taxi",
                    "parkingOptions": "Street Parking, Parking Garages",
                    "nearbyAttractions": "Grand Central Terminal, Bryant Park",
                    "bookingLink": "https://www.sakagura.com/reservations/",
                    "reservation": "Recommended",
                    "attire": "Casual",
                    "subactivities": [
                        {
                            "description": "Take a leisurely stroll through Bryant Park",
                            "conversationTopics": "Favorite outdoor activities, childhood memories",
                            "timeRequired": "30 minutes"
                        }
                    ]
                },
                {
                    "place": "Comedy Cellar",
                    "address": "117 Macdougal St, New York, NY 10012",
                    "cityState": "New York, NY",
                    "createdAt": "1982",
                    "dateOf": "2024",
                    "description": "Laugh the night away at the legendary Comedy Cellar with top stand-up comedians.",
                    "approximatedCost": "$$",
                    "openDateAndTime": "9:30 PM",
                    "datePlanStart": "9:30 PM",
                    "datePlanEnd": "11:00 PM",
                    "socialMediaLink": "https://www.instagram.com/comedycellarusa/",
                    "transportationOptions": "Subway, Taxi",
                    "parkingOptions": "Street Parking",
                    "nearbyAttractions": "Washington Square Park, NYU Campus",
                    "bookingLink": "https://www.comedycellar.com/",
                    "reservation": "Recommended",
                    "attire": "Casual",
                    "subactivities": [
                        {
                            "description": "Enjoy a quick walk around Washington Square Park",
                            "conversationTopics": "Favorite comedians, funny childhood stories",
                            "timeRequired": "20 minutes"
                        }
                    ]
                }
            ]
        }
    ]
}
